# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
img = cv2.imread('E:\Precision Farming Photos\20190722_Mobile_MiA1\20190722_Mobile_MiA1/2.jpg')
plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-fcb2d9ddbef4> in <module>
#       1 img = cv2.imread('E:\Precision Farming Photos\20190722_Mobile_MiA1\20190722_Mobile_MiA1/2.jpg')
# ----> 2 plt.imshow(img)
#
# ~\Miniconda3\envs\tensorflow\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2675         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2676         resample=resample, url=url, **({"data": data} if data is not
# -> 2677         None else {}), **kwargs)
#    2678     sci(__ret)
#    2679     return __ret
#
# ~\Miniconda3\envs\tensorflow\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
# ...

# %%
img = cv2.imread('E:\projects/3.jpg')
plt.imshow(img)

# %%
img = cv2.imread('E:\projects/tgA8_1_20190722_M.jpg')
plt.imshow(img)

# %%
img = cv2.imread('E:\leaves/4.jpg')
plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-5c4b8cea9dfb> in <module>
#       1 img = cv2.imread('E:\leaves/4.jpg')
# ----> 2 plt.imshow(img)
#
# ~\Miniconda3\envs\tensorflow\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2675         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2676         resample=resample, url=url, **({"data": data} if data is not
# -> 2677         None else {}), **kwargs)
#    2678     sci(__ret)
#    2679     return __ret
#
# ~\Miniconda3\envs\tensorflow\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# ...
